# %% [markdown]
# <a href="https://colab.research.google.com/github/alsedawy/sedawy/blob/main/CIFAR_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Add the module optimizer, datasets, layers (dense - conv2d - maxpool2d - flatten)
from tensorflow.keras import optimizers, datasets, layers
import tensorflow as tf
# Load Dataset (CIFAR-10)
(train_x, train_y),(test_x, test_y)=datasets.cifar10.load_data()
#Check the shape of data
train_x.shape
# Reshape it to become 3 D
train_x=train_x.reshape(50000, 32, 32, 3)
test_x=test_x.reshape(10000, 32, 32, 3)
train_x.shape
print(train_x[0])
# Normalization by devided to 255 to become from ( 0 to 1)
train_x=train_x.astype('float32')/255
test_x=test_x.astype('float32')/255
print(train_x[0])
print(train_y[0])
# To View Sanple image
import matplotlib.pyplot as plt
plt.imshow(train_x[0])
# conver as vector by one hot encoding
train_y=tf.keras.utils.to_categorical(train_y)
test_y=tf.keras.utils.to_categorical(test_y)
train_y[0]
from tensorflow.keras import activations, Sequential
# Build of layers
model1=Sequential()
# layer(conv2D) filter(5*5)32time/image strdid(1) padding(same) activation(ReLu) shap(3D)
model1.add(layers.Conv2D(filters=32,
    kernel_size=5,strides=1, padding="same",
    activation=tf.nn.relu, input_shape=(32,32,3)))
# Layed(Maxpool2D) window(2*2) strides=(2*2) Padding(valid)
model1.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2),padding='valid'))
# Layer(conv2D) filter(3*3)64time/image strdid(1) padding(same) activation(ReLu)
model1.add(layers.Conv2D(filters=64,
    kernel_size=3,strides=1, padding="same",
    activation=tf.nn.relu))
# Layer(Maxpool2D) window(2*2) strides=(2*2) Padding(valid)
model1.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2),padding='valid'))
# Layer(Flatten)
model1.add(layers.Flatten())
# Layer(dense) Nurel(128) activation(ReLu)
model1.add(layers.Dense(units=128, activation=tf.nn.relu))
# Output Layer(dense) Nurel(10) activation(Soft Max)
model1.add(layers.Dense(units=10,activation=tf.nn.softmax))
# compilation -- in Multi class [loss="categorical_crossentropy]
model1.compile(optimizer='adam', loss="categorical_crossentropy",metrics=['accuracy'])
# Fit validation(test_x,test_y)
hist=model1.fit(x=train_x, y=train_y,epochs=100,validation_data=(test_x,test_y),
      batch_size=128)
model1.summary()
# Summarize history for accurance
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model1 accturacy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'],loc='upper left')

# Summarize history for Loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model1 loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'],loc='upper left')
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# [[[ 59  62  63]
#   [ 43  46  45]
#   [ 50  48  43]
#   ...
#   [158 132 108]
#   [152 125 102]
#   [148 124 103]]
#
#  [[ 16  20  20]
#   [  0   0   0]
#   [ 18   8   0]
#   ...
#   [123  88  55]
#   [119  83  50]
#   [122  87  57]]
#
#  [[ 25  24  21]
#   [ 16   7   0]
#   [ 49  27   8]
#   ...
#   [118  84  50]
#   [120  84  50]
#   [109  73  42]]
#
#  ...
#
#  [[208 170  96]
#   [201 153  34]
#   [198 161  26]
#   ...
#   [160 133  70]
#   [ 56  31   7]
#   [ 53  34  20]]
#
#  [[180 139  96]
#   [173 123  42]
#   [186 144  30]
#   ...
#   [184 148  94]
#   [ 97  62  34]
#   [ 83  53  34]]
#
#  [[177 144 116]
#   [168 129  94]
#   [179 142  87]
#   ...
#   [216 184 140]
#   [151 118  84]
#   [123  92  72]]]
# [[[0.23137255 0.24313726 0.24705882]
#   [0.16862746 0.18039216 0.1764706 ]
#   [0.19607843 0.1882353  0.16862746]
#   ...
#   [0.61960787 0.5176471  0.42352942]
#   [0.59607846 0.49019608 0.4       ]
#   [0.5803922  0.4862745  0.40392157]]
#
#  [[0.0627451  0.07843138 0.07843138]
#   [0.         0.         0.        ]
#   [0.07058824 0.03137255 0.        ]
#   ...
#   [0.48235294 0.34509805 0.21568628]
#   [0.46666667 0.3254902  0.19607843]
#   [0.47843137 0.34117648 0.22352941]]
#
#  [[0.09803922 0.09411765 0.08235294]
#   [0.0627451  0.02745098 0.        ]
#   [0.19215687 0.10588235 0.03137255]
#   ...
#   [0.4627451  0.32941177 0.19607843]
#   [0.47058824 0.32941177 0.19607843]
#   [0.42745098 0.28627452 0.16470589]]
#
#  ...
#
#  [[0.8156863  0.6666667  0.3764706 ]
#   [0.7882353  0.6        0.13333334]
#   [0.7764706  0.6313726  0.10196079]
#   ...
#   [0.627451   0.52156866 0.27450982]
#   [0.21960784 0.12156863 0.02745098]
#   [0.20784314 0.13333334 0.07843138]]
#
#  [[0.7058824  0.54509807 0.3764706 ]
#   [0.6784314  0.48235294 0.16470589]
#   [0.7294118  0.5647059  0.11764706]
#   ...
#   [0.72156864 0.5803922  0.36862746]
#   [0.38039216 0.24313726 0.13333334]
#   [0.3254902  0.20784314 0.13333334]]
#
#  [[0.69411767 0.5647059  0.45490196]
#   [0.65882355 0.5058824  0.36862746]
#   [0.7019608  0.5568628  0.34117648]
#   ...
#   [0.84705883 0.72156864 0.54901963]
#   [0.5921569  0.4627451  0.32941177]
#   [0.48235294 0.36078432 0.28235295]]]
# [6]
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 91s 228ms/step - accuracy: 0.3741 - loss: 1.7320 - val_accuracy: 0.5409 - val_loss: 1.2810
# Epoch 2/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 88s 226ms/step - accuracy: 0.5854 - loss: 1.1728 - val_accuracy: 0.5933 - val_loss: 1.1650
# Epoch 3/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 88s 226ms/step - accuracy: 0.6388 - loss: 1.0267 - val_accuracy: 0.6518 - val_loss: 0.9880
# Epoch 4/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 147s 238ms/step - accuracy: 0.6841 - loss: 0.9023 - val_accuracy: 0.6832 - val_loss: 0.9096
# Epoch 5/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 88s 224ms/step - accuracy: 0.7184 - loss: 0.8061 - val_accuracy: 0.6841 - val_loss: 0.9126
# Epoch 6/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 93s 237ms/step - accuracy: 0.7441 - loss: 0.7403 - val_accuracy: 0.6869 - val_loss: 0.9146
# Epoch 7/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 88s 226ms/step - accuracy: 0.7694 - loss: 0.6676 - val_accuracy: 0.7113 - val_loss: 0.8445
# Epoch 8/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 143s 229ms/step - accuracy: 0.7876 - loss: 0.6123 - val_accuracy: 0.6988 - val_loss: 0.8711
# Epoch 9/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 227ms/step - accuracy: 0